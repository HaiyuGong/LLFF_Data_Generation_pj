# %%
import os
from PIL import Image
import pillow_heif

def convert_heic_to_jpg(heic_path, jpg_path):
    heif_file = pillow_heif.read_heif(heic_path)
    image = Image.frombytes(
        heif_file.mode,
        heif_file.size,
        heif_file.data,
        "raw",
        heif_file.mode,
        heif_file.stride,
    )
    image.save(jpg_path, "JPEG")

def batch_convert_heic_to_jpg(input_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for filename in os.listdir(input_dir):
        if filename.lower().endswith('.heic'):
            heic_path = os.path.join(input_dir, filename)
            jpg_filename = os.path.splitext(filename)[0] + '.jpg'
            jpg_path = os.path.join(output_dir, jpg_filename)
            convert_heic_to_jpg(heic_path, jpg_path)
            print(f"Converted {filename} to {jpg_filename}")

# 示例用法
os.makedirs(r"ania\images", exist_ok=True)
batch_convert_heic_to_jpg(r"C:\Users\GongHaiyu\Downloads\iCloud", r"ania\images")
# Out:
# Converted IMG_6315.HEIC to IMG_6315.jpg
# Converted IMG_6316.HEIC to IMG_6316.jpg
# Converted IMG_6317.HEIC to IMG_6317.jpg
# Converted IMG_6318.HEIC to IMG_6318.jpg
# Converted IMG_6319.HEIC to IMG_6319.jpg
# Converted IMG_6320.HEIC to IMG_6320.jpg
# Converted IMG_6321.HEIC to IMG_6321.jpg
# Converted IMG_6322.HEIC to IMG_6322.jpg
# Converted IMG_6323.HEIC to IMG_6323.jpg
# Converted IMG_6324.HEIC to IMG_6324.jpg
# Converted IMG_6325.HEIC to IMG_6325.jpg
# Converted IMG_6326.HEIC to IMG_6326.jpg
# Converted IMG_6327.HEIC to IMG_6327.jpg
# Converted IMG_6328.HEIC to IMG_6328.jpg
# Converted IMG_6329.HEIC to IMG_6329.jpg
# Converted IMG_6330.HEIC to IMG_6330.jpg
# Converted IMG_6331.HEIC to IMG_6331.jpg
# Converted IMG_6332.HEIC to IMG_6332.jpg
# Converted IMG_6333.HEIC to IMG_6333.jpg
# Converted IMG_6334.HEIC to IMG_6334.jpg
# Converted IMG_6335.HEIC to IMG_6335.jpg
# Converted IMG_6336.HEIC to IMG_6336.jpg
# Converted IMG_6337.HEIC to IMG_6337.jpg
# ...
